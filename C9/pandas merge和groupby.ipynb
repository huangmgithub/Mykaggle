# %% [markdown]
# ## pandas.merge的用法
#
#     pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
#          left_index=False, right_index=False, sort=True,
#          suffixes=('_x', '_y'), copy=True, indicator=False,
#          validate=None)

# %% [markdown]
# left 参与合并的左侧DataFrame
# right 参与合并的右侧DataFrame
# how 连接方式：‘inner’（默认）；还有，‘outer’、‘left’、‘right’
# on 用于连接的列名，必须同时存在于左右两个DataFrame对象中，如果位指定，则以left和right列名的交集作为连接键
# left_on 左侧DataFarme中用作连接键的列
# right_on 右侧DataFarme中用作连接键的列
# left_index 将左侧的行索引用作其连接键
# right_index 将右侧的行索引用作其连接键
# sort 根据连接键对合并后的数据进行排序，默认为True。有时在处理大数据集时，禁用该选项可获得更好的性能
# suffixes 字符串值元组，用于追加到重叠列名的末尾，默认为（‘_x’,‘_y’）.例如，左右两个DataFrame对象都有‘data’，则结果中就会出   现‘data_x’，‘data_y’

# %%
import pandas as pd

left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                      'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})


right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                     'D': ['D0', 'D1', 'D2', 'D3']})

result = pd.merge(left, right, on="key")

# %%
result.head()
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
import pandas as pd
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3'],
                      'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                     'D': ['D0', 'D1', 'D2', 'D3']})

result = pd.merge(left, right, left_on = "key1", right_on="key2")

# %%
result
# Out:
#   key1   A   B key2   C   D
# 0   K0  A0  B0   K0  C0  D0
# 1   K1  A1  B1   K1  C1  D1
# 2   K2  A2  B2   K2  C2  D2
# 3   K3  A3  B3   K3  C3  D3

# %% [markdown]
# ### merge删除重复列

# %%
result = pd.merge(left, right, left_on="key1", right_on="key2").drop("key1", axis=1)

# %%
result
# Out:
#     A   B key2   C   D
# 0  A0  B0   K0  C0  D0
# 1  A1  B1   K1  C1  D1
# 2  A2  B2   K2  C2  D2
# 3  A3  B3   K3  C3  D3

# %% [markdown]
# ### 参数how的用法-inner
#
# 默认：inner内连接，取交集

# %%
import pandas as pd

left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})

result = pd.merge(left, right, left_on="key1", right_on="key2", how="inner")

# %% [markdown]
# ### 参数how的用法-outer
#
# outer 外连接，取并集，并用nan填充

# %%
import pandas as pd

left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})

result = pd.merge(left, right, left_on='key1',right_on='key2',how='outer')
result
# Out:
#   key1    A    B key2    C    D
# 0   K0   A0   B0   K0   C0   D0
# 1   K1   A1   B1   K1   C1   D1
# 2   K2   A2   B2   K2   C2   D2
# 3   K3   A3   B3   K3   C3   D3
# 4   K4   A4   B4  NaN  NaN  NaN
# 5  NaN  NaN  NaN   K5   C4   D4

# %% [markdown]
# ### 参数how的用法-left
#
# left 左连接， 左侧取全部，右侧取部分

# %%
import pandas as pd
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})

result = pd.merge(left, right, left_on='key1',right_on='key2',how='left')
result
# Out:
#   key1   A   B key2    C    D
# 0   K0  A0  B0   K0   C0   D0
# 1   K1  A1  B1   K1   C1   D1
# 2   K2  A2  B2   K2   C2   D2
# 3   K3  A3  B3   K3   C3   D3
# 4   K4  A4  B4  NaN  NaN  NaN

# %% [markdown]
# ### 参数how的用法-right
#
# right 有连接，左侧取部分，右侧取全部

# %%
import pandas as pd
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})


result = pd.merge(left, right, left_on='key1',right_on='key2',how='right')
result
# Out:
#   key1    A    B key2   C   D
# 0   K0   A0   B0   K0  C0  D0
# 1   K1   A1   B1   K1  C1  D1
# 2   K2   A2   B2   K2  C2  D2
# 3   K3   A3   B3   K3  C3  D3
# 4  NaN  NaN  NaN   K5  C4  D4

# %% [markdown]
# ## pandas.groupby的用法

# %% [markdown]
# ### pandaas.groupby trainform的用法
# transform()方法+自定义方法

# %%
import pandas as pd
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("./input/test_set.csv")

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown

# %%
data.groupby("job")["age"].sum()
# Out:
# job
# admin.           48141
# blue-collar      92658
# entrepreneur     13948
# housemaid        14818
# management       93373
# retired          34032
# self-employed    15796
# services         37618
# student           6562
# technician       72539
# unemployed       13049
# unknown           2839
# Name: age, dtype: int64

# %%
# %%time
data['job_age_count']=data.groupby(['job'])['age'].transform(lambda x:x.count())
data['job_age_sum']=data.groupby(['job'])['age'].transform(lambda x:x.sum())
data['job_age_max']=data.groupby(['job'])['age'].transform(lambda x:x.max())
data['job_age_min']=data.groupby(['job'])['age'].transform(lambda x:x.min())
data['job_age_mean']=data.groupby(['job'])['age'].transform(lambda x:x.mean())
# Out:
# Wall time: 121 ms

# %%
data.head(20)
# Out:
#        ID  age          job   marital  education default  balance housing  \
# 0   25318   51    housemaid   married    unknown      no      174      no
# 1   25319   32   management   married   tertiary      no     6059     yes
# 2   25320   60      retired   married    primary      no        0      no
# 3   25321   32      student    single   tertiary      no       64      no
# 4   25322   41    housemaid   married  secondary      no        0     yes
# 5   25323   26   technician   married  secondary      no     -293     yes
# 6   25324   37     services   married  secondary      no      405     yes
# 7   25325   31      student    single   tertiary      no      117     yes
# 8   25326   45   management   married  secondary      no      424     yes
# 9   25327   33       admin.    single  secondary      no     1437     yes
# 10  25328   53   management   married   tertiary      no     2578      no
# 11  25329   35   technician    single  secondary      no     5731     yes
# 12  25330   55  blue-collar  divorced  secondary      no     -152     yes
# 13  25331   37  blue-collar    single  secondary      no      134     yes
# 14  25332   34     services    single  secondary      no     8132     yes
# 15  25333   37   technician    single  secondary      no      466     yes
# 16  25334   55   management   married   tertiary      no     3848     yes
# 17  25335   41     services   married  secondary      no     1483     yes
# 18  25336   46  blue-collar   married  secondary      no      345     yes
# 19  25337   33   management    single  secondary      no        0     yes
#
#    loan    contact  day month  duration  campaign  pdays  previous poutcome  \
# 0    no  telephone   29   jul       308         3     -1         0  unknown
# 1    no   cellular   20   nov       110         2     -1         0  unknown
# 2    no  telephone   30   jul       130         3     -1         0  unknown
# 3    no   cellular   30   jun       598         4    105         5  failure
# 4   yes   cellular   15   jul       368         4     -1         0  unknown
# 5   yes    unknown    5   jun        64         2     -1         0  unknown
# 6    no    unknown   21   may        51         2     -1         0  unknown
# 7    no  telephone   18   jul        41         1     -1         0  unknown
# 8   yes   cellular   12   aug       216         5     -1         0  unknown
# 9    no    unknown   21   may       641         1     -1         0  unknown
# 10   no   cellular    4   aug       958         2     -1         0  unknown
# 11   no   cellular    4   may       164         2    167         4    other
# 12   no   cellular    7   may        36         3     -1         0  unknown
# 13   no    unknown    8   may       200         1     -1         0  unknown
# 14   no    unknown   20   may       137         1     -1         0  unknown
# 15   no    unknown    3   jun       231         2     -1         0  unknown
# 16   no   cellular    8   apr       222         2     -1         0  unknown
# 17   no    unknown   17   jun        66         4     -1         0  unknown
# 18  yes  telephone    4   feb        86         1    259         3    other
# 19   no    unknown   26   may       816         2     -1         0  unknown
#
#     job_age_count  job_age_sum  job_age_max  job_age_min  job_age_mean
# 0             316        14818           83           23     46.892405
# 1            2299        93373           81           21     40.614615
# 2             555        34032           94           33     61.318919
# 3             249         6562           41           18     26.353414
# 4             316        14818           83           23     46.892405
# 5            1842        72539           70           21     39.380565
# 6             966        37618           60           20     38.942029
# 7             249         6562           41           18     26.353414
# 8            2299        93373           81           21     40.614615
# 9            1215        48141           69           20     39.622222
# 10           2299        93373           81           21     40.614615
# 11           1842        72539           70           21     39.380565
# 12           2307        92658           75           21     40.163849
# 13           2307        92658           75           21     40.163849
# 14            966        37618           60           20     38.942029
# 15           1842        72539           70           21     39.380565
# 16           2299        93373           81           21     40.614615
# 17            966        37618           60           20     38.942029
# 18           2307        92658           75           21     40.163849
# 19           2299        93373           81           21     40.614615

# %% [markdown]
# ### pandas.groupby trainform的用法
# transform()方法+python内置方法

# %%
# %%time
data['job_age_count1']=data.groupby(['job'])['age'].transform('count')
data['job_age_sum1']=data.groupby(['job'])['age'].transform(sum)
data['job_age_max1']=data.groupby(['job'])['age'].transform(max)
data['job_age_min1']=data.groupby(['job'])['age'].transform(min)
data['job_age_mean1']=data.groupby(['job'])['age'].transform('mean')
# Out:
# Wall time: 35.1 ms

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count  job_age_sum  job_age_max  job_age_min  job_age_mean  \
# 0            316        14818           83           23     46.892405
# 1           2299        93373           81           21     40.614615
# 2            555        34032           94           33     61.318919
# 3            249         6562           41           18     26.353414
# 4            316        14818           83           23     46.892405
#
#    job_age_count1  job_age_sum1  job_age_max1  job_age_min1  job_age_mean1
# 0             316         14818            83            23      46.892405
# 1            2299         93373            81            21      40.614615
# 2             555         34032            94            33      61.318919
# 3             249          6562            41            18      26.353414
# 4             316         14818            83            23      46.892405

# %% [markdown]
# ### pandas.groupby apply的用法
# apply()方法+自定义方法

# %%
# %%time
data['job_age_count']=data.groupby(['job'])['age'].apply(lambda x:x.count())
data['job_age_sum']=data.groupby(['job'])['age'].apply(lambda x:x.sum)
data['job_age_max']=data.groupby(['job'])['age'].apply(lambda x:x.max)
data['job_age_min']=data.groupby(['job'])['age'].apply(lambda x:x.min)
data['job_age_mean']=data.groupby(['job'])['age'].apply(lambda x:x.mean())
# Out:
# Wall time: 51.5 ms

# %%
def age_1(x1):
    y = x1 + 1
    return y

data["age_plus1"] = data["age"].apply(age_1)

# %%
data["age_plus2"] = data["age"].apply(lambda x: x + 1)

# %%
data[["age", "age_plus1", "age_plus2"]].head()
# Out:
#    age  age_plus1  age_plus2
# 0   51         52         52
# 1   32         33         33
# 2   60         61         61
# 3   32         33         33
# 4   41         42         42

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count job_age_sum job_age_max job_age_min  job_age_mean  \
# 0            NaN         NaN         NaN         NaN           NaN
# 1            NaN         NaN         NaN         NaN           NaN
# 2            NaN         NaN         NaN         NaN           NaN
# 3            NaN         NaN         NaN         NaN           NaN
# 4            NaN         NaN         NaN         NaN           NaN
#
#    job_age_count1  job_age_sum1  job_age_max1  job_age_min1  job_age_mean1  \
# 0             316         14818            83            23      46.892405
# 1            2299         93373            81            21      40.614615
# 2             555         34032            94            33      61.318919
# 3             249          6562            41            18      26.353414
# 4             316         14818            83            23      46.892405
#
#    age_plus1  age_plus2
# 0         52         52
# 1         33         33
# 2         61         61
# 3         33         33
# 4         42         42

# %% [markdown]
# ### pandas.groupby agg的用法
# agg()方法+自定义方法, 不会自动map

# %%
data.groupby(['job'])['age'].agg(lambda x:x.count())
data.groupby(['job'])['age'].agg(lambda x:x.sum)
data.groupby(['job'])['age'].agg(lambda x:x.max)
data.groupby(['job'])['age'].agg(lambda x:x.min)
data.groupby(['job'])['age'].agg(lambda x:x.mean())
# Out:
# job
# admin.           39.622222
# blue-collar      40.163849
# entrepreneur     42.395137
# housemaid        46.892405
# management       40.614615
# retired          61.318919
# self-employed    40.398977
# services         38.942029
# student          26.353414
# technician       39.380565
# unemployed       40.399381
# unknown          47.316667
# Name: age, dtype: float64

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count job_age_sum job_age_max job_age_min  job_age_mean  \
# 0            NaN         NaN         NaN         NaN           NaN
# 1            NaN         NaN         NaN         NaN           NaN
# 2            NaN         NaN         NaN         NaN           NaN
# 3            NaN         NaN         NaN         NaN           NaN
# 4            NaN         NaN         NaN         NaN           NaN
#
#    job_age_count1  job_age_sum1  job_age_max1  job_age_min1  job_age_mean1  \
# 0             316         14818            83            23      46.892405
# 1            2299         93373            81            21      40.614615
# 2             555         34032            94            33      61.318919
# 3             249          6562            41            18      26.353414
# 4             316         14818            83            23      46.892405
#
#    age_plus1  age_plus2
# 0         52         52
# 1         33         33
# 2         61         61
# 3         33         33
# 4         42         42

# %%
data.groupby(['job'])['age'].agg('count')
data.groupby(['job'])['age'].agg(sum)
data.groupby(['job'])['age'].agg(max)
data.groupby(['job'])['age'].agg(min)
data.groupby(['job'])['age'].agg('mean')
# Out:
# job
# admin.           39.622222
# blue-collar      40.163849
# entrepreneur     42.395137
# housemaid        46.892405
# management       40.614615
# retired          61.318919
# self-employed    40.398977
# services         38.942029
# student          26.353414
# technician       39.380565
# unemployed       40.399381
# unknown          47.316667
# Name: age, dtype: float64

# %%
aggcount=data.groupby(['job'])['age'].agg([('job_age_count2','count'),('job_age_sum2',sum),('job_age_max2',max),('job_age_min2',min),('job_age_mean2','mean')])

# %%
aggcount.head()
# Out:
#               job_age_count2  job_age_sum2  job_age_max2  job_age_min2  \
# job
# admin.                  1215         48141            69            20
# blue-collar             2307         92658            75            21
# entrepreneur             329         13948            84            26
# housemaid                316         14818            83            23
# management              2299         93373            81            21
#
#               job_age_mean2
# job
# admin.            39.622222
# blue-collar       40.163849
# entrepreneur      42.395137
# housemaid         46.892405
# management        40.614615

# %%
# agg后，merge相当于transform
data=pd.merge(data, aggcount,on='job',how='left')

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count job_age_sum job_age_max job_age_min  job_age_mean  \
# 0            NaN         NaN         NaN         NaN           NaN
# 1            NaN         NaN         NaN         NaN           NaN
# 2            NaN         NaN         NaN         NaN           NaN
# 3            NaN         NaN         NaN         NaN           NaN
# 4            NaN         NaN         NaN         NaN           NaN
#
#    job_age_count1  job_age_sum1  job_age_max1  job_age_min1  job_age_mean1  \
# 0             316         14818            83            23      46.892405
# 1            2299         93373            81            21      40.614615
# 2             555         34032            94            33      61.318919
# 3             249          6562            41            18      26.353414
# 4             316         14818            83            23      46.892405
#
#    age_plus1  age_plus2  job_age_count2  job_age_sum2  job_age_max2  \
# 0         52         52             316         14818            83
# 1         33         33            2299         93373            81
# 2         61         61             555         34032            94
# 3         33         33             249          6562            41
# 4         42         42             316         14818            83
#
#    job_age_min2  job_age_mean2
# 0            23      46.892405
# 1            21      40.614615
# 2            33      61.318919
# 3            18      26.353414
# 4            23      46.892405

# %% [markdown]
# ### pandas.groupby 众数特征

# %%
import scipy.stats as stats # stats.mode返回传入数组/矩阵中最常出现的成员以及出现的次数

data['job_age_mode'] = data.groupby(['job'])['age'].transform(lambda x:stats.mode(x)[0][0])
data['marital_age_mode']=data.groupby(['marital'])['age'].transform(lambda x:stats.mode(x)[0][0])

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count job_age_sum job_age_max job_age_min  job_age_mean  \
# 0            NaN         NaN         NaN         NaN           NaN
# 1            NaN         NaN         NaN         NaN           NaN
# 2            NaN         NaN         NaN         NaN           NaN
# 3            NaN         NaN         NaN         NaN           NaN
# 4            NaN         NaN         NaN         NaN           NaN
#
#    job_age_count1  job_age_sum1  job_age_max1  job_age_min1  job_age_mean1  \
# 0             316         14818            83            23      46.892405
# 1            2299         93373            81            21      40.614615
# 2             555         34032            94            33      61.318919
# 3             249          6562            41            18      26.353414
# 4             316         14818            83            23      46.892405
#
#    age_plus1  age_plus2  job_age_count2  job_age_sum2  job_age_max2  \
# 0         52         52             316         14818            83
# 1         33         33            2299         93373            81
# 2         61         61             555         34032            94
# 3         33         33             249          6562            41
# 4         42         42             316         14818            83
#
#    job_age_min2  job_age_mean2  job_age_mode  marital_age_mode
# 0            23      46.892405            54                34
# 1            21      40.614615            34                34
# 2            33      61.318919            59                34
# 3            18      26.353414            27                30
# 4            23      46.892405            54                34
